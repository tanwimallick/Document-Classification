# %% [markdown]
# # LLM Validation - Llama 3 70B Multi-class prediction
# In this experiment, we experiment with a more powerful, larger model to see if it produces better classification results than less powerful models. We use Groq AI, which has generous rate limits and allows for insanely fast inference.

# %%
from groq import Groq
import pandas as pd
import time

# %% [markdown]
# **Define inference function and prompt**

# %% [markdown]
# > I will paste an abstract from a research article, and I want you to classify it into one or more categories from the following list: Computer Science (1), Physics (2), Mathematics (3), Statistics (4), Quantitative Biology (5), Quantitative Finance (6). Each field has a number associated with it, shown in parentheses. Please respond with a number or list of numbers, like "1,2" or "4" that correspond to the fields to which you believe the research article belongs. An article can belong to multiple fields, but please only assign the article to a field if it is explicitly focused on topics from that field. Please only respond with the number(s), with nothing else. Please classify this abstract:

# %%
client = Groq(
    api_key="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",
)

# %%
def label_abstract(x):
    prompt = f'''I will paste an abstract from a research article, and I want you to classify it into one or more categories from the 
                 following list: Computer Science (1), Physics (2), Mathematics (3), Statistics (4), Quantitative Biology (5), Quantitative Finance (6). 
                 Each field has a number associated with it, shown in parentheses. Please respond with a number or list of numbers, like "1,2" or "4" 
                 that correspond to the fields to which you believe the research article belongs. An article can belong to multiple fields, but please 
                 only assign the article to a field if it is explicitly focused on topics from that field. Please only respond with the number(s), 
                 with nothing else. Please classify this abstract: {x}'''
    chat_completion = client.chat.completions.create(
        messages=[
            {
                "role": "user",
                "content": prompt,
            }
        ],
        model="llama3-70b-8192",
    )
    
    resp = chat_completion.choices[0].message.content
    print(resp)
    
    time.sleep(7)
    return resp

# %% [markdown]
# **Import data and run the model**:

# %%
test_set = pd.read_csv("data/test_set.csv")
test_set.head()
# Out:
#       ID                                              TITLE  \
# 0    475  Selecting optimal minimum spanning trees that ...
# 1  11242  A Markov Chain Model for the Cure Rate of Non-...
# 2    649  On Popov's formula involving the Von Mangoldt ...
# 3  15325             Retirement spending and biological age
# 4   1529  Social Network based Short-Term Stock Trading ...
#
#                                             ABSTRACT  Computer Science  \
# 0    Choi et. al (2011) introduced a minimum span...                 1
# 1    A Markov-chain model is developed for the pu...                 0
# 2    We offer a generalization of a formula of Po...                 0
# 3    We solve a lifecycle model in which the cons...                 0
# 4    This paper proposes a novel adaptive algorit...                 1
#
#    Physics  Mathematics  Statistics  Quantitative Biology  \
# 0        0            1           0                     0
# ...

# %%
test_set['Llama3_70B_multi'] = ''

# %%
test_set['Llama3_70B_multi'][:300] = test_set['ABSTRACT'][:300].apply(label_abstract)
# Out:
# 3, 4
# 6
# 3
# 5, 6
# 6
# 3
# 2
# 5, 6
# 1, 3
# 2,5
# 4, 5
# 1
# 5, 6
# 3, 5
# 2
# 4, 6
# 1, 3
# 1, 3
# 2,5
# 2, 5
# 3, 4
# 2
# 3
# 6,1
# 1
# 6
# 1, 4
# 4, 6
# 2
# 2, 3
# 6
# 1, 6
# 1, 2
# 3, 4
# 3, 4
# 4, 5
# 6
# 1, 3
# 6
# 1,3
# 4,6
# 4
# 3
# 2, 5
# 3, 4, 5
# 1, 4
# 1, 4
# 1, 4
# 3
# 1, 4
# 1, 4
# 4
# 5
# 3, 4
# 1, 4
# 4, 5
# 1, 4
# 3
# 1, 2
# 1, 4
# 3
# 1
# 3, 4
# 3, 5
# 1
# 2
# 3
# 1, 4
# 1, 3, 4
# 5, 6
# 5
# 2, 5
# 4
# 1,3
# 2
# 3, 4
# 1
# 1
# 1
# 2
# 1, 4
# 3, 4
# 1
# 1, 5
# 6, 4
# 1, 5
# 1
# 3
# 5
# 3, 4
# 3, 4
# 2, 5
# 4
# 2, 5
# 1, 3
# 1
# 2
# 2, 3
# 5
# 3
# 5, 6
# 1, 3
# 3, 4, 5
# 2, 5
# 6, 4
# 2
# 1, 2
# 2
# 1, 5
# 4, 1
# 1
# 2
# 6
# 1, 5
# 4,6
# 2
# 3
# 1, 3
# 1, 4
# 1, 4
# 1, 3
# 1
# 4, 6
# 4, 5
# 2,5
# 3
# 3, 4
# 2
# 3
# 1, 5
# 1, 4
# 3
# 1
# 2
# 4,5
# 1,4
# 2, 3
# 6
# 2, 6
# 1, 4
# 4, 6
# 1
# 1
# 2, 3
# 2
# 4
# 5, 6
# 5
# 5
# 4
# 6
# 1, 4
# 3
# 1
# 2
# 1, 5, 6
# 5, 4
# 1
# 1, 3
# 1
# 6
# 1
# 2
# 4, 6
# 1, 3
# 1
# 2, 3
# 1
# 1, 4
# 3
# 1, 4
# 4
# 4, 5, 6
# 1, 4
# 6
# 1
# ...

# %%
test_set['Llama3_70B_multi'][300:600] = test_set['ABSTRACT'][300:600].apply(label_abstract)
# Out:
# 3, 4
# 1, 3
# 5, 4
# 2, 5
# 3
# 5
# 1, 3
# 1, 3, 4
# 2, 3
# 4, 6
# 1, 4
# 1,4
# 1, 4
# 1, 3
# 2, 4
# 2, 5
# 5,6
# 2
# 4
# 2,3
# 6,1
# 5
# 5, 6
# 3
# 3, 4
# 3
# 2
# 3
# ---------------------------------------------------------------------------
# InternalServerError                       Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 test_set['Llama3_70B_multi'][300:600] = test_set['ABSTRACT'][300:600].apply(label_abstract)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\series.py:4760, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4625 def apply(
#    4626     self,
#    4627     func: AggFuncType,
#    (...)
#    4632     **kwargs,
#    4633 ) -> DataFrame | Series:
#    4634     """
#    4635     Invoke function on values of Series.
#    4636
#    (...)
#    4751     dtype: float64
#    4752     """
#    4753     return SeriesApply(
#    4754         self,
#    4755         func,
# ...

# %%
test_set
# Out:
#          ID                                              TITLE  \
# 0       475  Selecting optimal minimum spanning trees that ...
# 1     11242  A Markov Chain Model for the Cure Rate of Non-...
# 2       649  On Popov's formula involving the Von Mangoldt ...
# 3     15325             Retirement spending and biological age
# 4      1529  Social Network based Short-Term Stock Trading ...
# ...     ...                                                ...
# 1049    429  On generalizations of $p$-sets and their appli...
# 1050    830  A Comprehensive Study of Ly$α$ Emission in the...
# 1051    222  SPIRou Input Catalog: Activity, Rotation and M...
# 1052    663  Multiscale Modeling of Shock Wave Localization...
# 1053  14554  Spatial risk measures induced by powers of max...
#
#                                                ABSTRACT  Computer Science  \
# 0       Choi et. al (2011) introduced a minimum span...                 1
# ...

# %%
df_labeled.to_csv("llama3_70b_experiment.csv")

# %% [markdown]
# ### Evaluating Llama3 70B

# %%
df_labeled = pd.read_csv("data/llama3_70b_experiment.csv")
df_labeled.head()
# Out:
#                                             abstract  CS_actual  Llama3_70B_CS
# 0    Predictive models allow subject-specific inf...          1              1
# 1    Rotation invariance and translation invarian...          1              1
# 2    We introduce and develop the notion of spher...          0              0
# 3    The stochastic Landau--Lifshitz--Gilbert (LL...          0              0
# 4    Fourier-transform infra-red (FTIR) spectra o...          1              1

# %%
# Source: https://medium.com/@dtuk81/confusion-matrix-visualization-fc31e3f30fea

from sklearn.metrics import confusion_matrix
import seaborn as sns
import numpy as np

cm = confusion_matrix(df_labeled['CS_actual'], df_labeled['Llama3_70B_CS'])

group_names = ['True Neg','False Pos','False Neg','True Pos']
group_counts = ["{0:0.0f}".format(value) for value in
                cm.flatten()]
group_percentages = ["{0:.2%}".format(value) for value in
                     cm.flatten()/np.sum(cm)]
labels = [f"{v1}\n{v2}\n{v3}" for v1, v2, v3 in
          zip(group_names,group_counts,group_percentages)]
labels = np.asarray(labels).reshape(2,2)

sns.heatmap(cm, annot=labels, fmt="", cmap='Blues')
# Out:
# <Axes: >

# %%
tn = cm[0][0]
fp = cm[0][1]
fn = cm[1][0]
tp = cm[1][1]

# Accuracy: the percent of correctly classified data
accuracy = (tn+tp)/(tn+fp+fn+tp)
accuracy
# Out:
# 0.895

# %%
# Precision: positive predictive value; of those predicted as CS documents, how many were actually CS documents?
precision = (tp)/(tp+fp)
precision
# Out:
# 0.8202247191011236

# %%
# Recall: of those that were actually CS documents, how many were predicted as CS documents?
recall = (tp)/(tp+fn)
recall
# Out:
# 0.9358974358974359

# %%
    # F1 score: tries to balance precision and recall, with uneven class distribution (large number of actual negs)
    f1 = 2*((precision*recall)/(precision+recall))
    f1
# Out:
# 0.874251497005988

# %% [markdown]
# This is the best model so far! It scores better than in-context learning Llama 3 8B on virtually every metric: higher accuracy (84% vs. 89.5%), higher precision (74% vs. 82%), higher recall (91% vs. 93%), and a higher F1-score (0.81 vs. 0.87). It shows that more powerful models will probably classify documents better, similar to how more powerful, larger embedding models did better than smaller ones. Notably, inference in this experiment was also incredibly fast, since I used Groq AI, which has pretty generous rate limits.

# %% [markdown]
# ### Qualitative analysis

# %% [markdown]
# This model misclassified 21 documents in the dataset, representing around ~10% of the dataset. We will now see what mistakes it makes. Previous qualitative analysis has yielded that many consistently
